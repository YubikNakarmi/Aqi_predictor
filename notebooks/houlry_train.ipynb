# %%
import pandas as pd

# Use the installed package (editable install)
from modules import data_hourly_preprocessing as data_prep
from modules.data_hourly_preprocessing import DataCleaner

# %%
# !pip install -e /pypipeline/.
# Out:
# Obtaining file:///D:/pypipeline
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for pypipeline (pyproject.toml): started
#   Building editable for pypipeline (pyproject.toml): finished with status 'done'
#   Created wheel for pypipeline: filename=pypipeline-0.0.0-0.editable-py3-none-any.whl size=1621 sha256=9f7e8bc8d03a6013fb9a037528624544f2aec91c7a180ccde3f27d05db65fca4
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 import pandas as pd
# ----> 2 from src.modules import data_hourly_preprocessing as data_prep
#
# ModuleNotFoundError: No module named 'src'

# %%
main_data = DataCleaner()

# %%
# Instantiate train/val/test cleaners
train_obj = DataCleaner()
val_obj = DataCleaner()
test_obj = DataCleaner()

# %%
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

train_end = int(len(forcasting) * train_ratio)
val_end = int(len(forcasting) * (train_ratio + val_ratio))

df_train = forcasting.iloc[:train_end]
df_val = forcasting.iloc[train_end:val_end]
df_test = forcasting.iloc[val_end:]
